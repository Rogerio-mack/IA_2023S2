# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IA_2023S2/blob/main/SUB_IA_2023S2_7G.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="Universidade Presbiteriana Mackenzie">
# </head>
#
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg" width=300, align="right">
# <!-- <h1 align=left><font size = 6, style="color:rgb(200,0,0)"> optional title </font></h1> -->

# %% [markdown]
# # **IA SUB 2023S2**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Classificação de Tipos de Vidro
#
# Vidros de podem ser classificados 7 categorias conforme suas características químicas:
#
# * Classe 1: janelas de construção (processadas com flutuação)
# * Classe 2: janelas de construção (processadas sem flutuação)
# * Classe 3: janelas do veículo (processadas com flutuação)
# * Classe 4: janelas do veículo (processadas sem flutuação)
# * Classe 5: recipientes
# * Classe 6: talheres
# * Classe 7: faróis
#
# (*algumas classes podem não estar presentes no data-set*).

# %%
df = pd.read_csv('https://github.com/Rogerio-mack/IA_2023S2/raw/main/glasses.csv')
df.head()
# Out:
#    Id number             receipt name  receipt       RI     Na Mg    Al  \
# 0          1        Arthur Nascimento     9009  1.52101  13.64  D  1.10
# 1          2            Kamilly Lopes    13268  1.51761  13.89  D  1.36
# 2          3          Yasmin da Costa    21037  1.51618  13.53  C  1.54
# 3          4   Vitor Gabriel Teixeira    15457  1.51766  13.21  D  1.29
# 4          5  Maria Fernanda da Cunha     2792  1.51742  13.27  D  1.24
#
#       Si     K    Ca   Ba   Fe  Type of glass
# 0  71.78  0.06  8.75  0.0  0.0              1
# 1  72.73  0.48  7.83  0.0  0.0              1
# 2  72.99  0.39  7.78  0.0  0.0              1
# 3  72.61  0.57  8.22  0.0  0.0              1
# 4  73.08  0.55  8.07  0.0  0.0              1

# %% [markdown]
# # Pré-Exercício 1
#
# Aqui interessa podermos classificar os vidros para efeito de reciclagem em 3 categorias:
#
# * **C = Vidros de Construção**
# * **V = Vidros de Veículos**
# * **O = Outros**
#
# Reclassifique `Type of glass` para os valores 'C', 'V' e 'O'. Sugestão: empregue o `Pandas` `replace()`.

# %% [markdown]
# # Exercícios 1
#
# Construa um modelo de classificação qualquer entre árvores de decisão, regressão logística e k-vizinhos mais próximos obtendo a acuracidade sobre um conjunto de teste de 30% dos dados.

# %%
# seu código

# %% [markdown]
# # Exercícios 2
#
# Construa um modelo de classificação MLP obtendo a acuracidade sobre um conjunto de teste de 30% dos dados.

# %%
# seu código

# %% [markdown]
# # Exercícios 3
#
# Faça uma clusterização dos dados, kmédias ou hierárquica, e forneça a taxa de classificação obtida (a exemplo do que fizemos na N2).

# %%
# seu código
